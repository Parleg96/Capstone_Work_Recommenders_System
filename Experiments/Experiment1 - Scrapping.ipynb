# %% [markdown]
# # Example 1

# %%
#Python program to scrape website
#and save quotes from website
import requests
from bs4 import BeautifulSoup
import csv

URL = "http://www.values.com/inspirational-quotes"
r = requests.get(URL)

soup = BeautifulSoup(r.content, 'html5lib')

quotes=[] # a list to store quotes

table = soup.find('div', attrs = {'id':'all_quotes'})

for row in table.findAll('div',
						attrs = {'class':'col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top'}):
	quote = {}
	quote['theme'] = row.h5.text
	quote['url'] = row.a['href']
	quote['img'] = row.img['src']
	quote['lines'] = row.img['alt'].split(" #")[0]
	quote['author'] = row.img['alt'].split(" #")[1]
	quotes.append(quote)

filename = 'inspirational_quotes.csv'
with open(filename, 'w', newline='') as f:
	w = csv.DictWriter(f,['theme','url','img','lines','author'])
	w.writeheader()
	for quote in quotes:
		w.writerow(quote)

# %%
import pandas as pd
pd.read_csv(filename)
# Out:
#           theme                                                url  \
# 0         PEACE  /inspirational-quotes/3571-when-the-power-of-l...
# 1         PEACE  /inspirational-quotes/8312-peace-is-a-day-to-d...
# 2         PEACE  /inspirational-quotes/8311-inner-peace-doesn-t...
# 3         PEACE  /inspirational-quotes/8310-peace-is-its-own-re...
# 4         PEACE  /inspirational-quotes/7582-it-isn-t-enough-to-...
# 5      OPTIMISM  /inspirational-quotes/8308-optimism-is-a-strat...
# 6      OPTIMISM  /inspirational-quotes/7376-and-you-ask-what-if...
# 7      OPTIMISM  /inspirational-quotes/8309-it-s-not-that-optim...
# 8      OPTIMISM  /inspirational-quotes/4506-perpetual-optimism-...
# 9      OPTIMISM  /inspirational-quotes/7017-no-pessimist-ever-d...
# 10   CONFIDENCE  /inspirational-quotes/8307-stay-afraid-but-do-...
# 11   CONFIDENCE  /inspirational-quotes/7199-one-must-have-the-a...
# 12   CONFIDENCE    /inspirational-quotes/8306-be-proud-to-wear-you
# ...

# %% [markdown]
# # Example2

# %%
import requests
URL = "https://www.yummytummyaarthi.com/paneer-manchurian-recipe-how-to-make/"
r = requests.get(URL).text
#print(r.content)

# %% [markdown]
# #### Creating text file of raw html content

# %%
import os
os.chdir('C:\\Users\\Priyanka G\\Web_Scrapping_Files')

# %%
import requests
URL = "https://www.yummytummyaarthi.com/paneer-manchurian-recipe-how-to-make/"
r1 = requests.get(URL)
type(r1)
# Out:
# requests.models.Response

# %%
with open ('sample_dish.txt', 'w', encoding="utf-8") as f:
    f.write(r1.text)

# %% [markdown]
# ## Example 3

# %%
import os
os.chdir('C:\\Users\\Priyanka G')

# %%
#This will not run on online IDE
import requests
from bs4 import BeautifulSoup

URL = "https://www.yummytummyaarthi.com/paneer-manchurian-recipe-how-to-make/"
r = requests.get(URL)

soup = BeautifulSoup(r.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
#   <title>
#    Paneer Manchurian | Paneer Manchurian Recipe
#   </title>
#   <meta content="Delicious paneer manchurian which taste so delicious with fried rice or noodles. This taste amazing when served hot." name="description"/>
#   <link href="https://www.yummytummyaarthi.com/paneer-manchurian-recipe-how-to-make/" rel="canonical"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="article" property="og:type"/>
#   <meta content="Paneer Manchurian Recipe" property="og:title"/>
#   <meta content="Delicious paneer manchurian which taste so delicious with fried rice or noodles. This taste amazing when served hot." property="og:description"/>
# ...

# %%
table2 = soup.find('ul', attrs = {'class':"wprm-recipe-ingredients"})
print(table2.prettify)
# Out:
# <bound method Tag.prettify of <ul class="wprm-recipe-ingredients"><li class="wprm-recipe-ingredient" data-uid="0" style="list-style-type: none;"><span class="wprm-checkbox-container"><input aria-label="Paneer - 200 grams cubed" class="wprm-checkbox" id="wprm-checkbox-0" type="checkbox"/><label class="wprm-checkbox-label" for="wprm-checkbox-0"><span class="sr-only screen-reader-text wprm-screen-reader-text">▢ </span></label></span><span class="wprm-recipe-ingredient-name">Paneer - 200 grams cubed</span></li></ul>>

# %%
recipes=[]
file=open( "dish.txt","w")
for word in soup.find_all('span',attrs={'class':'wprm-recipe-ingredient-name'}):
  
    recipe={}
    # Obtain the text from the received
    # tags
    recipe['Ingredients']=word.get_text()
  
    # Print the text obtained received 
    # in previous step
    recipes.append(recipe)
    
    soup_link=str(word)
    file.write(soup_link)
    
file.flush()
file.close
# Out:
# <function TextIOWrapper.close()>

# %%
recipes
# Out:
# [{'Ingredients': 'Paneer - 200 grams cubed'},
#  {'Ingredients': 'All Purpose Flour / Maida - ½ cup'},
#  {'Ingredients': 'Cornflour / Cornstarch - ¼ cup'},
#  {'Ingredients': 'Salt to taste'},
#  {'Ingredients': 'Red Chilli Powder - 1 tsp'},
#  {'Ingredients': 'Soy Sauce - 1 tsp'},
#  {'Ingredients': 'Ginger Garlic paste - 1 tsp'},
#  {'Ingredients': 'Water - ½ cup or as needed'},
#  {'Ingredients': 'Oil - 5 to 8 tblspn'},
#  {'Ingredients': 'Onion - 1 medium size chopped'},
#  {'Ingredients': 'Celery - 1 chopped finely'},
#  {'Ingredients': 'Capsicum - ½ chopped'},
#  {'Ingredients': 'Tomato - 1 chopped'},
#  {'Ingredients': 'Ginger Garlic Paste - 1 tblspn'},
#  {'Ingredients': 'Green Chillies - 2 chopped'},
#  {'Ingredients': 'Salt to taste'},
#  {'Ingredients': 'Sugar - 1 tsp'},
#  {'Ingredients': 'Chilli Powder - 2 tsp'},
#  {'Ingredients': 'Tomato Ketchup - 3 to 4 tblspn'},
#  {'Ingredients': 'Soy Sauce - 2 tsp'},
#  {'Ingredients': 'Vinegar - 1 tsp or to taste'},
# ...

# %%
filename = 'panneer_recipe.csv'
with open(filename, 'w', newline='') as f:
    w = csv.DictWriter(f,['Ingredients'])
    w.writeheader()
    for recipe in recipes:
        w.writerow(recipe)

# %%
pd.read_csv(filename)
# Out:
#                                           Ingredients
# 0                            Paneer - 200 grams cubed
# 1                   All Purpose Flour / Maida - � cup
# 2                      Cornflour / Cornstarch - � cup
# 3                                       Salt to taste
# 4                           Red Chilli Powder - 1 tsp
# 5                                   Soy Sauce - 1 tsp
# 6                         Ginger Garlic paste - 1 tsp
# 7                          Water - � cup or as needed
# 8                                 Oil - 5 to 8 tblspn
# 9                       Onion - 1 medium size chopped
# 10                          Celery - 1 chopped finely
# 11                               Capsicum - � chopped
# 12                                 Tomato - 1 chopped
# 13                     Ginger Garlic Paste - 1 tblspn
# 14                         Green Chillies - 2 chopped
# 15                                      Salt to taste
# ...

# %%
import os
os.chdir('C:\\Users\\Priyanka G')

# %% [markdown]
# ## Example 4

# %%
import requests
URL = "https://www.yummytummyaarthi.com/paneer-manchurian-recipe-how-to-make/"
r1 = requests.get(URL).text

# %%
from bs4 import BeautifulSoup

text = ' '.join(BeautifulSoup(r1, "html.parser").findAll(text=True))

# %%
text
# Out:
# 'html \n \n \n \n \n \n Paneer Manchurian | Paneer Manchurian Recipe \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n {"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://www.yummytummyaarthi.com/#website","url":"https://www.yummytummyaarthi.com/","name":"Yummy Tummy","description":"Food blog that features step-by-step photos veg recipes of India, Indian healthy recipes, American recipes, baking recipes, chicken recipes, mutton recipes, sea food recipes, baby food recipes, easy baking recipes, cakes recipes, international recipes and many more.","publisher":{"@id":"https://www.yummytummyaarthi.com/#/schema/person/6a144dafcf6dc9ef511862a62d3d8e86"},"potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://www.yummytummyaarthi.com/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"ImageObject","@id":"https://www.yummytummyaarthi.com/paneer-manc
# ...

# %% [markdown]
# ## Example 5

# %%
from bs4 import BeautifulSoup

clean_text = ' '.join(BeautifulSoup(r1, "html.parser").stripped_strings)

# %%
clean_text
# Out:
# "Paneer Manchurian | Paneer Manchurian Recipe Skip to primary navigation Skip to main content Skip to primary sidebar Home Recipe Index About Me Masterchef Journey Travel Advertisers Media Search menu icon Home Recipe Index About Me Masterchef Journey Travel Media Advertisers Facebook Instagram Pinterest Twitter YouTube subscribe search icon Search Home Recipe Index About Me Masterchef Journey Travel Media Advertisers Facebook Instagram Pinterest Twitter YouTube × Home Paneer Manchurian Recipe January 13, 2022 By Aarthi 9 Comments Twitter Facebook 73 Pinterest Telegram WhatsApp Yummly 73 SHARES Jump to Recipe Print Recipe Delicious paneer manchurian which taste so delicious with fried rice or noodles. Pin TABLE OF CONTENTS 1. What is a Manchurian 2. Paneer Manchurian | Paneer Manchurian Recipe | Recipe for Paneer Manchurian 3. Paneer Manchurian Gravy Step by Step 4. Healthy Paneer Manchurian Dry Paneer manchurian Paneer Manchurian, my favourite. I love it to the core.. It goes well w
# ...

# %% [markdown]
# ## Example 6

# %%
os.chdir('D:\Spark_install\Lib\site-packages')
import html2text

# %%
h = html2text.HTML2Text()
# Ignore converting links from HTML
h.ignore_links = True
result = h.handle(r1)
print(result)
# Out:
#   * Skip to primary navigation
#   * Skip to main content
#   * Skip to primary sidebar
#
# ![Yummy Tummy](https://www.yummytummyaarthi.com/wp-
# content/uploads/2017/05/tummy.png)
#
#   * Home
#   * Recipe Index
#   * About Me
#   * Masterchef Journey
#   * Travel
#   * Advertisers
#   * Media
#   * Search
#
# menu icon
#
# ![go to homepage](https://www.yummytummyaarthi.com/wp-
# content/uploads/2021/10/logo-mobile.png)
#
#   * Home
#   * Recipe Index
#   * About Me
#   * Masterchef Journey
#   * Travel
#   * Media
#   * Advertisers
#
# *   * Facebook
#   * Instagram
#   * Pinterest
#   * Twitter
#   * YouTube
#
# subscribe
#
# search icon
#
# ![Homepage link](https://www.yummytummyaarthi.com/wp-
# content/uploads/2021/10/logo-mobile.png)
#
# Search
#
#   * Home
#   * Recipe Index
#   * About Me
#   * Masterchef Journey
#   * Travel
#   * Media
#   * Advertisers
#
# *   * Facebook
#   * Instagram
#   * Pinterest
#   * Twitter
#   * YouTube
#
# ×
#
# Home
#
# ...

# %%
with open ('sample_dish.txt', 'w', encoding="utf-8") as f:
    f.write(result)

# %%
os.getcwd()
# Out:
# 'D:\\Spark_install\\Lib\\site-packages'

# %%
import requests
URL = "https://www.vegrecipesofindia.com/paneer-manchurian-dry-recipe/"
r2 = requests.get(URL).text

# %%
h = html2text.HTML2Text()
# Ignore converting links from HTML
h.ignore_links = True
result = h.handle(r2)
print(result)
# Out:
# Skip to content
#
# MenuClose
#
# Dassana's Veg Recipes
#
# SearchClose
#
#   * Home
#   * Recipe Index
#   * About
#   * Follow Us
#
# Facebook YouTube Pinterest Twitter Instagram
#
# Search for
#
#   * Home
#   * Recipes
#   * About
#
# Home » **Recipes** » Snacks Recipes
#
# # Paneer Manchurian - 2 Ways (Dry and Gravy)
#
# ![](data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%2048%2048'%3E%3C/svg%3E)![](https://secure.gravatar.com/avatar/1f1e0a18cf458d170463061bfd17da5c?s=48&d=mm&r=g)By
# Dassana Amit
# Last Updated: June 16, 2021
#
# Vegetarian
# 4.78 from 18 votes • 42 Comments
#
# FacebookPinTweetWhatsAppEmailShares4.1k
#
# Jump to Recipe
#
# ![dry paneer manchurian recipe, paneer manchurian
# recipe](https://www.vegrecipesofindia.com/wp-content/uploads/2014/12/paneer-
# manchurian-recipe-280x280.jpg)
#
# ![Paneer Manchurian](https://www.vegrecipesofindia.com/wp-
# content/uploads/2014/12/Dry-paneer-manchurian-280x280.jpg)
#
# ...
